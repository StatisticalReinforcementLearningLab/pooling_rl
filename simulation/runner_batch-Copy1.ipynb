# %%
import sim_all
# Out:
# ------------------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-1-5faffd92a4f4> in <module>
# ----> 1 import sim_all
#
# ~/pooling_rl/simulation/sim_all.py in <module>
#      21 import study
#      22 import time as time_module
# ---> 23 import simple_bandits
#      24 import TS_personal_params_pooled as pp
#      25 import TS_global_params_pooled as gtp
#
# ~/pooling_rl/models/simple_bandits.py in <module>
# ----> 1 import gpflow
#       2 import numpy as np
#       3 import math
#       4 import tensorflow as tf
#       5 import sys
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/gpflow/__init__.py in <module>
#      17
#      18 from ._version import __version__
# ---> 19 from ._settings import SETTINGS as settings
#      20
#      21 from .session_manager import get_session
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/gpflow/_settings.py in <module>
#      10
#      11 import numpy as np
# ...

# %%
sim_all.run_many('batch',['case_one','case_two','case_three'],0,1,7,'../../Downloads/distributions/','../../Downloads/pooling_results/','None')
