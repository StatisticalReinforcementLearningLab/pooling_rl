# %%
import sim_all

# %%
sim_all.run_many('batch',['case_one','case_two','case_three'],0,50,1,'../../Downloads/distributions/','../../Downloads/pooling_results/','None')
# Out:
# [ 0.05  0.25  0.25  0.25 -0.3 ]
# None
# [0.05 0.25 0.25 0.25 0.3 ]
# None
# [0.05 0.25 0.25 0.25 0.3 ]
# None
# [ 0.05  0.25  0.25  0.25 -0.3 ]
# None
# [ 0.05  0.25  0.25  0.25 -0.3 ]
# None
# [0.05 0.25 0.25 0.25 0.3 ]
# None
# [ 0.05  0.25  0.25  0.25 -0.3 ]
# None
# [0.05 0.25 0.25 0.25 0.3 ]
# None
# [ 0.05  0.25  0.25  0.25 -0.3 ]
# None
# [0.05 0.25 0.25 0.25 0.3 ]
# None
# [ 0.05  0.25  0.25  0.25 -0.3 ]
# None
# [0.05 0.25 0.25 0.25 0.3 ]
# None
# [0.05 0.25 0.25 0.25 0.3 ]
# None
# [ 0.05  0.25  0.25  0.25 -0.3 ]
# None
# [ 0.05  0.25  0.25  0.25 -0.3 ]
# None
# [ 0.05  0.25  0.25  0.25 -0.3 ]
# None
# [0.05 0.25 0.25 0.25 0.3 ]
# None
# [0.05 0.25 0.25 0.25 0.3 ]
# None
# [ 0.05  0.25  0.25  0.25 -0.3 ]
# None
# [0.05 0.25 0.25 0.25 0.3 ]
# None
# [ 0.05  0.25  0.25  0.25 -0.3 ]
# None
# [0.05 0.25 0.25 0.25 0.3 ]
# None
# [0.05 0.25 0.25 0.25 0.3 ]
# None
# [ 0.05  0.25  0.25  0.25 -0.3 ]
# None
# [ 0.05  0.25  0.25  0.25 -0.3 ]
# None
# [ 0.05  0.25  0.25  0.25 -0.3 ]
# ...
