# %%
import numpy as np
import pickle
import os
import math
import matplotlib.pyplot as plt
import math
import numpy as np
import sys
sys.path
from scipy import stats
sys.path.append('../models')
sys.path.append('../simulation')
import TS_personal_params_pooled as pp
import TS_global_params_pooled as gtp
# %matplotlib inline

# %%
with open('../../Downloads/pooling_results/personalized/case_three/population_size_32_update_days_7_short_static_sim_49_four_effects_625.pkl','rb') as f:
    pooled = pickle.load(f)

# %%
pooled['pprams'].mus2
# Out:
# {0: array([ 0.75995618,  0.24451158, -0.20902693,  0.35789364,  0.29535596]),
#  1: array([ 1.27547517, -0.18011851,  0.14361244, -0.27880631,  0.10396848]),
#  2: array([ 1.09619135, -0.09640642,  0.47424444,  0.60036222, -0.15581648]),
#  3: array([ 0.5092755 , -0.07298133,  0.60010087,  0.11484838,  0.31319774]),
#  4: array([ 1.05199257,  0.02366027, -0.200382  ,  0.24088908,  0.51140682]),
#  5: array([ 0.18330118,  0.11071901,  0.09435108,  0.58284305, -0.66261895]),
#  6: array([ 1.27614518, -0.16133629, -0.16274018, -0.17989114,  0.35033644]),
#  7: array([ 0.67306097,  0.28055104, -0.07978135, -0.13952734, -0.23799847]),
#  8: array([ 0.45732794,  0.1606792 ,  0.07431174, -0.11454601,  0.19766852]),
#  9: array([-0.58364696, -0.05581192,  0.06121829, -0.29649921,  0.3477293 ]),
#  10: array([ 1.81218674, -0.05170465,  0.06112114, -0.4855762 , -0.0801352 ]),
#  11: array([ 0.37450274,  0.23483688,  0.195457  , -0.08570891,  0.17856265]),
#  12: array([ 1.86430307, -0.39822293, -0.08678079, -0.10479486, -0.59338754]),
#  13: array([ 0.67792405, -0.43856537,  0.57890065,  0.06874148, -0.49978413]),
#  14: array([ 0.94425141, -0.3057241 , -0.30073729,  0.45348   ,  0.2193624 ]),
#  15: array([ 0.41776014, -0.62319582,  0.08157997, -0.0715134 , -0.07720085]),
#  16: array([ 1.17972397, -0.58860417, -0.08673269,  0.10048843, -0.05488318]),
#  17: array([ 0.85194717,  0.12381451,  0.38781325, -0.16894054, -0.5084781 ]),
#  18: array([ 0.05996873,  0.24452456,  0.3625175 , -0.23486426, -0.68829518]),
#  19: array([ 0.76658937,  0.18882262, -0.01807782, -0.03801836, -0.31027214]),
#  20: array([ 0.70884345, -0.02492065, -0.43405189, -0.10553725, -0.11057325]),
#  21: array([ 0.86148719, -0.10108823,  0.07335583, -0.00124852,  0.17198821]),
#  22: array([ 1.30879161, -0.20955436, -0.71332289, -0.10648838, -0.65310756]),
#  23: array([-0.05939937,  0.12549968,  0.24720583,  0.04668148, -0.13974179]),
#  24: array([ 0.97866765, -0.17122878,  0.44311586,  0.08575229,  0.02591324]),
#  25: array([ 0.32932375, -0.09141406,  0.26216731,  0.20787107, -0.3876157 ]),
#  26: array([ 0.69018158, -0.09968863, -0.24720446,  0.19331578,  0.01275306]),
#  27: array([ 0.40342921, -0.21476408, -0.37451466,  0.37893274,  0.09528653]),
#  28: array([ 0.71969613, -0.18691383,  0.0183915 , -0.0085371 ,  0.50145854]),
#  29: array([ 0.28393391,  0.01702589,  0.0917796 , -0.14569866,  0.24736302]),
#  30: array([ 1.8255666 , -0.30032143, -0.09036778, -0.1571126 , -0.35509498]),
#  31: array([ 0.85513363,  0.47072058,  0.14985574, -0.47454344,  0.1493256 ])}
