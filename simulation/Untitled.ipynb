# %%
the_String = '\\begin{tabular}{lrr}\n\\toprule\n{} &  truncated\\_mean &  truncated\\_scale \\\\\n\\midrule\ngid-1-tod-0-dow-0-loc-0-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-0-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-0-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-0-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-0-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-0-pre-1-yst-1-var-0 &             0.0 &         1077.348 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-0-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-0-pre-1-yst-2-var-0 &             0.0 &         1367.939 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-1-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-1-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-1-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-1-pre-1-yst-0-var-0 &             0.0 &          768.214 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-1-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-1-pre-1-yst-1-var-0 &             0.0 &          891.118 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-1-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-1-pre-1-yst-2-var-0 &             0.0 &         1120.970 \\\\\ngid-1-tod-0-dow-0-loc-0-wea-1-pre-1-yst-2-var-1 &             0.0 &         1246.140 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-0-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-0-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-0-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-0-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-0-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-0-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-0-pre-1-yst-2-var-0 &             0.0 &         1367.939 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-1-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-1-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-1-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-1-pre-1-yst-0-var-0 &             0.0 &          768.214 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-1-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-1-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-1-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-1-pre-1-yst-2-var-0 &             0.0 &         1120.970 \\\\\ngid-1-tod-0-dow-0-loc-1-wea-1-pre-1-yst-2-var-1 &             0.0 &         1246.140 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-0-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-0-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-0-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-0-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-0-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-0-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-0-pre-1-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-1-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-1-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-1-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-1-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-1-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-1-pre-1-yst-1-var-0 &             0.0 &          891.118 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-1-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-1-pre-1-yst-2-var-0 &             0.0 &         1120.970 \\\\\ngid-1-tod-0-dow-0-loc-2-wea-1-pre-1-yst-2-var-1 &             0.0 &         1246.140 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-0-pre-0-yst-1-var-0 &             0.0 &          479.831 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-0-pre-0-yst-1-var-1 &             0.0 &          479.831 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-0-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-0-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-0-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-0-pre-1-yst-1-var-0 &             0.0 &         1077.348 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-0-pre-1-yst-1-var-1 &             0.0 &         1077.348 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-0-pre-1-yst-2-var-0 &             0.0 &         1367.939 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-1-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-1-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-1-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-1-pre-1-yst-0-var-0 &             0.0 &          768.214 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-1-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-1-pre-1-yst-1-var-0 &             0.0 &          891.118 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-1-pre-1-yst-1-var-1 &             0.0 &          891.118 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-1-pre-1-yst-2-var-0 &             0.0 &         1120.970 \\\\\ngid-1-tod-0-dow-0-loc-3-wea-1-pre-1-yst-2-var-1 &             0.0 &         1246.140 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-0-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-0-pre-0-yst-2-var-0 &             0.0 &          484.441 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-0-pre-1-yst-0-var-0 &             0.0 &          354.264 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-0-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-0-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-0-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-0-pre-1-yst-2-var-0 &             0.0 &         1573.578 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-1-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-1-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-1-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-1-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-1-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-1-pre-1-yst-1-var-0 &             0.0 &          842.556 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-1-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-1-pre-1-yst-2-var-0 &             0.0 &         1437.428 \\\\\ngid-1-tod-0-dow-1-loc-0-wea-1-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-0-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-0-pre-0-yst-2-var-0 &             0.0 &          484.441 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-0-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-0-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-0-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-0-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-0-pre-1-yst-2-var-0 &             0.0 &         1573.578 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-1-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-1-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-1-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-1-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-1-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-1-pre-1-yst-1-var-0 &             0.0 &          842.556 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-1-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-1-pre-1-yst-2-var-0 &             0.0 &         1437.428 \\\\\ngid-1-tod-0-dow-1-loc-1-wea-1-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-0-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-0-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-0-pre-1-yst-0-var-0 &             0.0 &          354.264 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-0-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-0-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-0-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-0-pre-1-yst-2-var-0 &             0.0 &         1573.578 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-1-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-1-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-1-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-1-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-1-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-1-pre-1-yst-1-var-0 &             0.0 &          842.556 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-1-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-1-pre-1-yst-2-var-0 &             0.0 &         1437.428 \\\\\ngid-1-tod-0-dow-1-loc-2-wea-1-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-0-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-0-pre-0-yst-2-var-0 &             0.0 &          484.441 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-0-pre-1-yst-0-var-0 &             0.0 &          354.264 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-0-pre-1-yst-0-var-1 &             0.0 &          354.264 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-0-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-0-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-0-pre-1-yst-2-var-0 &             0.0 &         1573.578 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-1-pre-0-yst-0-var-1 &             0.0 &          219.850 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-1-pre-0-yst-1-var-1 &             0.0 &          190.174 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-1-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-1-pre-1-yst-0-var-0 &             0.0 &          644.004 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-1-pre-1-yst-0-var-1 &             0.0 &          468.023 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-1-pre-1-yst-1-var-0 &             0.0 &          842.556 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-1-pre-1-yst-1-var-1 &             0.0 &          842.556 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-1-pre-1-yst-2-var-0 &             0.0 &         1437.428 \\\\\ngid-1-tod-0-dow-1-loc-3-wea-1-pre-1-yst-2-var-1 &             0.0 &         1437.428 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-0-pre-0-yst-0-var-0 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-0-pre-0-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-0-pre-0-yst-1-var-0 &             0.0 &          479.831 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-0-pre-0-yst-1-var-1 &             0.0 &          479.831 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-0-pre-0-yst-2-var-0 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-0-pre-0-yst-2-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-0-pre-1-yst-0-var-0 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-0-pre-1-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-0-pre-1-yst-1-var-0 &             0.0 &         1077.348 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-0-pre-1-yst-1-var-1 &             0.0 &         1077.348 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-0-pre-1-yst-2-var-0 &             0.0 &         1367.939 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-0-pre-1-yst-2-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-1-pre-0-yst-0-var-0 &             0.0 &          266.369 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-1-pre-0-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-1-pre-0-yst-1-var-0 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-1-pre-0-yst-1-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-1-pre-0-yst-2-var-0 &             0.0 &          423.096 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-1-pre-0-yst-2-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-1-pre-1-yst-0-var-0 &             0.0 &          768.214 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-1-pre-1-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-1-pre-1-yst-1-var-0 &             0.0 &          891.118 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-1-pre-1-yst-1-var-1 &             0.0 &          891.118 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-1-pre-1-yst-2-var-0 &             0.0 &         1120.970 \\\\\ngid-1-tod-1-dow-0-loc-0-wea-1-pre-1-yst-2-var-1 &             0.0 &         1246.140 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-0-pre-0-yst-0-var-0 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-0-pre-0-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-0-pre-0-yst-1-var-0 &             0.0 &          479.831 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-0-pre-0-yst-1-var-1 &             0.0 &          479.831 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-0-pre-0-yst-2-var-0 &             0.0 &          524.795 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-0-pre-0-yst-2-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-0-pre-1-yst-0-var-0 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-0-pre-1-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-0-pre-1-yst-1-var-0 &             0.0 &         1077.348 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-0-pre-1-yst-1-var-1 &             0.0 &         1077.348 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-0-pre-1-yst-2-var-0 &             0.0 &         1367.939 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-0-pre-1-yst-2-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-1-pre-0-yst-0-var-0 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-1-pre-0-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-1-pre-0-yst-1-var-0 &             0.0 &          489.710 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-1-pre-0-yst-1-var-1 &             0.0 &          489.710 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-1-pre-0-yst-2-var-0 &             0.0 &          423.096 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-1-pre-0-yst-2-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-1-pre-1-yst-0-var-0 &             0.0 &          768.214 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-1-pre-1-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-1-pre-1-yst-1-var-0 &             0.0 &          891.118 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-1-pre-1-yst-1-var-1 &             0.0 &          891.118 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-1-pre-1-yst-2-var-0 &             0.0 &         1120.970 \\\\\ngid-1-tod-1-dow-0-loc-1-wea-1-pre-1-yst-2-var-1 &             0.0 &         1246.140 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-0-pre-0-yst-0-var-0 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-0-pre-0-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-0-pre-0-yst-1-var-0 &             0.0 &          479.831 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-0-pre-0-yst-1-var-1 &             0.0 &          479.831 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-0-pre-0-yst-2-var-0 &             0.0 &          524.795 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-0-pre-0-yst-2-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-0-pre-1-yst-0-var-0 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-0-pre-1-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-0-pre-1-yst-1-var-0 &             0.0 &         1077.348 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-0-pre-1-yst-1-var-1 &             0.0 &         1077.348 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-0-pre-1-yst-2-var-0 &             0.0 &         1367.939 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-0-pre-1-yst-2-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-1-pre-0-yst-0-var-0 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-1-pre-0-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-1-pre-0-yst-1-var-0 &             0.0 &          489.710 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-1-pre-0-yst-1-var-1 &             0.0 &          489.710 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-1-pre-0-yst-2-var-0 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-1-pre-0-yst-2-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-1-pre-1-yst-0-var-0 &             0.0 &          768.214 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-1-pre-1-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-1-pre-1-yst-1-var-0 &             0.0 &          891.118 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-1-pre-1-yst-1-var-1 &             0.0 &          891.118 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-1-pre-1-yst-2-var-0 &             0.0 &         1120.970 \\\\\ngid-1-tod-1-dow-0-loc-2-wea-1-pre-1-yst-2-var-1 &             0.0 &         1246.140 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-0-pre-0-yst-0-var-0 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-0-pre-0-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-0-pre-0-yst-1-var-0 &             0.0 &          479.831 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-0-pre-0-yst-1-var-1 &             0.0 &          479.831 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-0-pre-0-yst-2-var-0 &             0.0 &          525.773 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-0-pre-0-yst-2-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-0-pre-1-yst-0-var-0 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-0-pre-1-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-0-pre-1-yst-1-var-0 &             0.0 &         1077.348 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-0-pre-1-yst-1-var-1 &             0.0 &         1077.348 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-0-pre-1-yst-2-var-0 &             0.0 &         1367.939 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-0-pre-1-yst-2-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-1-pre-0-yst-0-var-0 &             0.0 &          278.483 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-1-pre-0-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-1-pre-0-yst-1-var-0 &             0.0 &          489.429 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-1-pre-0-yst-1-var-1 &             0.0 &          489.429 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-1-pre-0-yst-2-var-0 &             0.0 &          424.371 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-1-pre-0-yst-2-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-1-pre-1-yst-0-var-0 &             0.0 &          768.214 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-1-pre-1-yst-0-var-1 &             0.0 &          933.978 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-1-pre-1-yst-1-var-0 &             0.0 &          891.118 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-1-pre-1-yst-1-var-1 &             0.0 &          891.118 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-1-pre-1-yst-2-var-0 &             0.0 &         1120.970 \\\\\ngid-1-tod-1-dow-0-loc-3-wea-1-pre-1-yst-2-var-1 &             0.0 &         1246.140 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-0-pre-0-yst-0-var-0 &             0.0 &          242.841 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-0-pre-0-yst-0-var-1 &             0.0 &          242.841 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-0-pre-0-yst-1-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-0-pre-0-yst-1-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-0-pre-0-yst-2-var-0 &             0.0 &          484.441 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-0-pre-0-yst-2-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-0-pre-1-yst-0-var-0 &             0.0 &          354.264 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-0-pre-1-yst-0-var-1 &             0.0 &          354.264 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-0-pre-1-yst-1-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-0-pre-1-yst-1-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-0-pre-1-yst-2-var-0 &             0.0 &         1573.578 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-0-pre-1-yst-2-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-1-pre-0-yst-0-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-1-pre-0-yst-0-var-1 &             0.0 &          219.850 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-1-pre-0-yst-1-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-1-pre-0-yst-1-var-1 &             0.0 &          190.174 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-1-pre-0-yst-2-var-0 &             0.0 &          417.841 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-1-pre-0-yst-2-var-1 &             0.0 &          417.841 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-1-pre-1-yst-0-var-0 &             0.0 &          644.004 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-1-pre-1-yst-0-var-1 &             0.0 &          468.023 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-1-pre-1-yst-1-var-0 &             0.0 &          842.556 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-1-pre-1-yst-1-var-1 &             0.0 &          842.556 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-1-pre-1-yst-2-var-0 &             0.0 &         1437.428 \\\\\ngid-1-tod-1-dow-1-loc-0-wea-1-pre-1-yst-2-var-1 &             0.0 &         1437.428 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-0-pre-0-yst-0-var-0 &             0.0 &          242.841 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-0-pre-0-yst-0-var-1 &             0.0 &          242.841 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-0-pre-0-yst-1-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-0-pre-0-yst-1-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-0-pre-0-yst-2-var-0 &             0.0 &          484.441 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-0-pre-0-yst-2-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-0-pre-1-yst-0-var-0 &             0.0 &          354.264 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-0-pre-1-yst-0-var-1 &             0.0 &          354.264 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-0-pre-1-yst-1-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-0-pre-1-yst-1-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-0-pre-1-yst-2-var-0 &             0.0 &         1573.578 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-0-pre-1-yst-2-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-1-pre-0-yst-0-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-1-pre-0-yst-0-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-1-pre-0-yst-1-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-1-pre-0-yst-1-var-1 &             0.0 &          190.174 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-1-pre-0-yst-2-var-0 &             0.0 &          417.841 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-1-pre-0-yst-2-var-1 &             0.0 &          417.841 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-1-pre-1-yst-0-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-1-pre-1-yst-0-var-1 &             0.0 &          468.023 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-1-pre-1-yst-1-var-0 &             0.0 &          842.556 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-1-pre-1-yst-1-var-1 &             0.0 &          842.556 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-1-pre-1-yst-2-var-0 &             0.0 &         1437.428 \\\\\ngid-1-tod-1-dow-1-loc-1-wea-1-pre-1-yst-2-var-1 &             0.0 &         1437.428 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-0-pre-0-yst-0-var-0 &             0.0 &          242.841 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-0-pre-0-yst-0-var-1 &             0.0 &          242.841 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-0-pre-0-yst-1-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-0-pre-0-yst-1-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-0-pre-0-yst-2-var-0 &             0.0 &          484.441 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-0-pre-0-yst-2-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-0-pre-1-yst-0-var-0 &             0.0 &          354.264 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-0-pre-1-yst-0-var-1 &             0.0 &          354.264 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-0-pre-1-yst-1-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-0-pre-1-yst-1-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-0-pre-1-yst-2-var-0 &             0.0 &         1573.578 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-0-pre-1-yst-2-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-1-pre-0-yst-0-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-1-pre-0-yst-0-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-1-pre-0-yst-1-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-1-pre-0-yst-1-var-1 &             0.0 &          190.174 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-1-pre-0-yst-2-var-0 &             0.0 &          417.841 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-1-pre-0-yst-2-var-1 &             0.0 &          417.841 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-1-pre-1-yst-0-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-1-pre-1-yst-0-var-1 &             0.0 &          468.023 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-1-pre-1-yst-1-var-0 &             0.0 &          842.556 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-1-pre-1-yst-1-var-1 &             0.0 &          842.556 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-1-pre-1-yst-2-var-0 &             0.0 &         1437.428 \\\\\ngid-1-tod-1-dow-1-loc-2-wea-1-pre-1-yst-2-var-1 &             0.0 &         1437.428 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-0-pre-0-yst-0-var-0 &             0.0 &          242.841 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-0-pre-0-yst-0-var-1 &             0.0 &          242.841 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-0-pre-0-yst-1-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-0-pre-0-yst-1-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-0-pre-0-yst-2-var-0 &             0.0 &          484.441 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-0-pre-0-yst-2-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-0-pre-1-yst-0-var-0 &             0.0 &          354.264 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-0-pre-1-yst-0-var-1 &             0.0 &          354.264 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-0-pre-1-yst-1-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-0-pre-1-yst-1-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-0-pre-1-yst-2-var-0 &             0.0 &         1573.578 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-0-pre-1-yst-2-var-1 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-1-pre-0-yst-0-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-1-pre-0-yst-0-var-1 &             0.0 &          219.850 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-1-pre-0-yst-1-var-0 &             0.0 &         1078.478 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-1-pre-0-yst-1-var-1 &             0.0 &          190.174 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-1-pre-0-yst-2-var-0 &             0.0 &          417.841 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-1-pre-0-yst-2-var-1 &             0.0 &          417.841 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-1-pre-1-yst-0-var-0 &             0.0 &          644.004 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-1-pre-1-yst-0-var-1 &             0.0 &          468.023 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-1-pre-1-yst-1-var-0 &             0.0 &          842.556 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-1-pre-1-yst-1-var-1 &             0.0 &          842.556 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-1-pre-1-yst-2-var-0 &             0.0 &         1437.428 \\\\\ngid-1-tod-1-dow-1-loc-3-wea-1-pre-1-yst-2-var-1 &             0.0 &         1437.428 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-0-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-0-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-0-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-0-pre-1-yst-0-var-1 &             0.0 &          680.972 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-0-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-0-pre-1-yst-1-var-1 &             0.0 &          835.973 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-0-pre-1-yst-2-var-0 &             0.0 &          588.705 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-1-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-1-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-1-pre-0-yst-2-var-1 &             0.0 &          409.997 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-1-pre-1-yst-0-var-0 &             0.0 &          507.548 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-1-pre-1-yst-0-var-1 &             0.0 &          588.413 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-1-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-1-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-1-pre-1-yst-2-var-0 &             0.0 &          644.659 \\\\\ngid-2-tod-0-dow-0-loc-0-wea-1-pre-1-yst-2-var-1 &             0.0 &          616.768 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-0-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-0-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-0-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-0-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-0-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-0-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-0-pre-1-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-1-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-1-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-1-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-1-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-1-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-1-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-1-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-1-pre-1-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-1-wea-1-pre-1-yst-2-var-1 &             0.0 &          616.768 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-0-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-0-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-0-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-0-pre-1-yst-0-var-1 &             0.0 &          680.972 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-0-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-0-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-0-pre-1-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-1-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-1-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-1-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-1-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-1-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-1-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-1-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-1-pre-1-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-2-wea-1-pre-1-yst-2-var-1 &             0.0 &          616.768 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-0-pre-0-yst-0-var-1 &             0.0 &          198.589 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-0-pre-0-yst-1-var-1 &             0.0 &          144.482 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-0-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-0-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-0-pre-1-yst-0-var-1 &             0.0 &          680.972 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-0-pre-1-yst-1-var-0 &             0.0 &          457.553 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-0-pre-1-yst-1-var-1 &             0.0 &          835.973 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-0-pre-1-yst-2-var-0 &             0.0 &          588.705 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-1-pre-0-yst-0-var-1 &             0.0 &          263.667 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-1-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-1-pre-0-yst-2-var-1 &             0.0 &          409.997 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-1-pre-1-yst-0-var-0 &             0.0 &          507.548 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-1-pre-1-yst-0-var-1 &             0.0 &          588.413 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-1-pre-1-yst-1-var-0 &             0.0 &          540.063 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-1-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-1-pre-1-yst-2-var-0 &             0.0 &          644.659 \\\\\ngid-2-tod-0-dow-0-loc-3-wea-1-pre-1-yst-2-var-1 &             0.0 &          616.768 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-0-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-0-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-0-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-0-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-0-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-0-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-0-pre-1-yst-2-var-0 &             0.0 &          665.168 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-1-pre-0-yst-0-var-1 &             0.0 &          219.850 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-1-pre-0-yst-1-var-1 &             0.0 &          190.174 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-1-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-1-pre-1-yst-0-var-0 &             0.0 &          644.004 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-1-pre-1-yst-0-var-1 &             0.0 &          468.023 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-1-pre-1-yst-1-var-0 &             0.0 &          616.545 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-1-pre-1-yst-1-var-1 &             0.0 &          453.519 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-1-pre-1-yst-2-var-0 &             0.0 &          672.336 \\\\\ngid-2-tod-0-dow-1-loc-0-wea-1-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-0-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-0-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-0-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-0-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-0-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-0-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-0-pre-1-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-1-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-1-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-1-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-1-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-1-pre-1-yst-0-var-1 &             0.0 &          468.023 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-1-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-1-pre-1-yst-1-var-1 &             0.0 &          453.519 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-1-pre-1-yst-2-var-0 &             0.0 &          672.336 \\\\\ngid-2-tod-0-dow-1-loc-1-wea-1-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-0-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-0-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-0-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-0-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-0-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-0-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-0-pre-1-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-1-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-1-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-1-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-1-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-1-pre-1-yst-0-var-1 &             0.0 &          468.023 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-1-pre-1-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-1-pre-1-yst-1-var-1 &             0.0 &          453.519 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-1-pre-1-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-2-wea-1-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-0-pre-0-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-0-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-0-pre-1-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-0-pre-1-yst-0-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-0-pre-1-yst-1-var-0 &             0.0 &          549.803 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-0-pre-1-yst-1-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-0-pre-1-yst-2-var-0 &             0.0 &          665.168 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-0-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-1-pre-0-yst-0-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-1-pre-0-yst-0-var-1 &             0.0 &          219.850 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-1-pre-0-yst-1-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-1-pre-0-yst-1-var-1 &             0.0 &          190.174 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-1-pre-0-yst-2-var-0 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-1-pre-0-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-1-pre-1-yst-0-var-0 &             0.0 &          644.004 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-1-pre-1-yst-0-var-1 &             0.0 &          468.023 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-1-pre-1-yst-1-var-0 &             0.0 &          616.545 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-1-pre-1-yst-1-var-1 &             0.0 &          453.519 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-1-pre-1-yst-2-var-0 &             0.0 &          672.336 \\\\\ngid-2-tod-0-dow-1-loc-3-wea-1-pre-1-yst-2-var-1 &             0.0 &            0.000 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-0-pre-0-yst-0-var-0 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-0-pre-0-yst-0-var-1 &             0.0 &          198.589 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-0-pre-0-yst-1-var-0 &             0.0 &          304.839 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-0-pre-0-yst-1-var-1 &             0.0 &          144.482 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-0-pre-0-yst-2-var-0 &             0.0 &          334.395 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-0-pre-0-yst-2-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-0-pre-1-yst-0-var-0 &             0.0 &          365.875 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-0-pre-1-yst-0-var-1 &             0.0 &          680.972 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-0-pre-1-yst-1-var-0 &             0.0 &          457.553 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-0-pre-1-yst-1-var-1 &             0.0 &          835.973 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-0-pre-1-yst-2-var-0 &             0.0 &          588.705 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-0-pre-1-yst-2-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-1-pre-0-yst-0-var-0 &             0.0 &          315.849 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-1-pre-0-yst-0-var-1 &             0.0 &          263.667 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-1-pre-0-yst-1-var-0 &             0.0 &          355.788 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-1-pre-0-yst-1-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-1-pre-0-yst-2-var-0 &             0.0 &          414.793 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-1-pre-0-yst-2-var-1 &             0.0 &          409.997 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-1-pre-1-yst-0-var-0 &             0.0 &          507.548 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-1-pre-1-yst-0-var-1 &             0.0 &          588.413 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-1-pre-1-yst-1-var-0 &             0.0 &          540.063 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-1-pre-1-yst-1-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-1-pre-1-yst-2-var-0 &             0.0 &          644.659 \\\\\ngid-2-tod-1-dow-0-loc-0-wea-1-pre-1-yst-2-var-1 &             0.0 &          616.768 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-0-pre-0-yst-0-var-0 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-0-pre-0-yst-0-var-1 &             0.0 &          198.589 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-0-pre-0-yst-1-var-0 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-0-pre-0-yst-1-var-1 &             0.0 &          144.482 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-0-pre-0-yst-2-var-0 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-0-pre-0-yst-2-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-0-pre-1-yst-0-var-0 &             0.0 &          365.875 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-0-pre-1-yst-0-var-1 &             0.0 &          680.972 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-0-pre-1-yst-1-var-0 &             0.0 &          457.553 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-0-pre-1-yst-1-var-1 &             0.0 &          835.973 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-0-pre-1-yst-2-var-0 &             0.0 &          588.705 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-0-pre-1-yst-2-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-1-pre-0-yst-0-var-0 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-1-pre-0-yst-0-var-1 &             0.0 &          263.667 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-1-pre-0-yst-1-var-0 &             0.0 &          355.788 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-1-pre-0-yst-1-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-1-pre-0-yst-2-var-0 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-1-pre-0-yst-2-var-1 &             0.0 &          409.997 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-1-pre-1-yst-0-var-0 &             0.0 &          507.548 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-1-pre-1-yst-0-var-1 &             0.0 &          588.413 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-1-pre-1-yst-1-var-0 &             0.0 &          540.063 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-1-pre-1-yst-1-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-1-pre-1-yst-2-var-0 &             0.0 &          644.659 \\\\\ngid-2-tod-1-dow-0-loc-1-wea-1-pre-1-yst-2-var-1 &             0.0 &          616.768 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-0-pre-0-yst-0-var-0 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-0-pre-0-yst-0-var-1 &             0.0 &          198.589 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-0-pre-0-yst-1-var-0 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-0-pre-0-yst-1-var-1 &             0.0 &          144.482 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-0-pre-0-yst-2-var-0 &             0.0 &          334.395 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-0-pre-0-yst-2-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-0-pre-1-yst-0-var-0 &             0.0 &          365.875 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-0-pre-1-yst-0-var-1 &             0.0 &          680.972 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-0-pre-1-yst-1-var-0 &             0.0 &          457.553 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-0-pre-1-yst-1-var-1 &             0.0 &          835.973 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-0-pre-1-yst-2-var-0 &             0.0 &          588.705 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-0-pre-1-yst-2-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-1-pre-0-yst-0-var-0 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-1-pre-0-yst-0-var-1 &             0.0 &          263.667 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-1-pre-0-yst-1-var-0 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-1-pre-0-yst-1-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-1-pre-0-yst-2-var-0 &             0.0 &          414.793 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-1-pre-0-yst-2-var-1 &             0.0 &          409.997 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-1-pre-1-yst-0-var-0 &             0.0 &          507.548 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-1-pre-1-yst-0-var-1 &             0.0 &          588.413 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-1-pre-1-yst-1-var-0 &             0.0 &          540.063 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-1-pre-1-yst-1-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-1-pre-1-yst-2-var-0 &             0.0 &          644.659 \\\\\ngid-2-tod-1-dow-0-loc-2-wea-1-pre-1-yst-2-var-1 &             0.0 &          616.768 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-0-pre-0-yst-0-var-0 &             0.0 &          158.916 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-0-pre-0-yst-0-var-1 &             0.0 &          198.589 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-0-pre-0-yst-1-var-0 &             0.0 &          305.323 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-0-pre-0-yst-1-var-1 &             0.0 &          144.482 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-0-pre-0-yst-2-var-0 &             0.0 &          334.922 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-0-pre-0-yst-2-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-0-pre-1-yst-0-var-0 &             0.0 &          365.875 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-0-pre-1-yst-0-var-1 &             0.0 &          680.972 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-0-pre-1-yst-1-var-0 &             0.0 &          457.553 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-0-pre-1-yst-1-var-1 &             0.0 &          835.973 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-0-pre-1-yst-2-var-0 &             0.0 &          588.705 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-0-pre-1-yst-2-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-1-pre-0-yst-0-var-0 &             0.0 &          319.955 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-1-pre-0-yst-0-var-1 &             0.0 &          263.667 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-1-pre-0-yst-1-var-0 &             0.0 &          356.100 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-1-pre-0-yst-1-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-1-pre-0-yst-2-var-0 &             0.0 &          415.052 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-1-pre-0-yst-2-var-1 &             0.0 &          409.997 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-1-pre-1-yst-0-var-0 &             0.0 &          507.548 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-1-pre-1-yst-0-var-1 &             0.0 &          588.413 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-1-pre-1-yst-1-var-0 &             0.0 &          540.063 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-1-pre-1-yst-1-var-1 &             0.0 &          441.997 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-1-pre-1-yst-2-var-0 &             0.0 &          644.659 \\\\\ngid-2-tod-1-dow-0-loc-3-wea-1-pre-1-yst-2-var-1 &             0.0 &          616.768 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-0-pre-0-yst-0-var-0 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-0-pre-0-yst-0-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-0-pre-0-yst-1-var-0 &             0.0 &          242.385 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-0-pre-0-yst-1-var-1 &             0.0 &          242.385 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-0-pre-0-yst-2-var-0 &             0.0 &          264.385 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-0-pre-0-yst-2-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-0-pre-1-yst-0-var-0 &             0.0 &          477.624 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-0-pre-1-yst-0-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-0-pre-1-yst-1-var-0 &             0.0 &          549.803 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-0-pre-1-yst-1-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-0-pre-1-yst-2-var-0 &             0.0 &          665.168 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-0-pre-1-yst-2-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-1-pre-0-yst-0-var-0 &             0.0 &          185.048 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-1-pre-0-yst-0-var-1 &             0.0 &          219.850 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-1-pre-0-yst-1-var-0 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-1-pre-0-yst-1-var-1 &             0.0 &          190.174 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-1-pre-0-yst-2-var-0 &             0.0 &          351.264 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-1-pre-0-yst-2-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-1-pre-1-yst-0-var-0 &             0.0 &          644.004 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-1-pre-1-yst-0-var-1 &             0.0 &          468.023 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-1-pre-1-yst-1-var-0 &             0.0 &          616.545 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-1-pre-1-yst-1-var-1 &             0.0 &          453.519 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-1-pre-1-yst-2-var-0 &             0.0 &          672.336 \\\\\ngid-2-tod-1-dow-1-loc-0-wea-1-pre-1-yst-2-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-0-pre-0-yst-0-var-0 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-0-pre-0-yst-0-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-0-pre-0-yst-1-var-0 &             0.0 &          242.385 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-0-pre-0-yst-1-var-1 &             0.0 &          242.385 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-0-pre-0-yst-2-var-0 &             0.0 &          264.385 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-0-pre-0-yst-2-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-0-pre-1-yst-0-var-0 &             0.0 &          477.624 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-0-pre-1-yst-0-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-0-pre-1-yst-1-var-0 &             0.0 &          549.803 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-0-pre-1-yst-1-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-0-pre-1-yst-2-var-0 &             0.0 &          665.168 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-0-pre-1-yst-2-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-1-pre-0-yst-0-var-0 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-1-pre-0-yst-0-var-1 &             0.0 &          219.850 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-1-pre-0-yst-1-var-0 &             0.0 &          221.835 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-1-pre-0-yst-1-var-1 &             0.0 &          190.174 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-1-pre-0-yst-2-var-0 &             0.0 &          351.264 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-1-pre-0-yst-2-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-1-pre-1-yst-0-var-0 &             0.0 &          644.004 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-1-pre-1-yst-0-var-1 &             0.0 &          468.023 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-1-pre-1-yst-1-var-0 &             0.0 &          616.545 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-1-pre-1-yst-1-var-1 &             0.0 &          453.519 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-1-pre-1-yst-2-var-0 &             0.0 &          672.336 \\\\\ngid-2-tod-1-dow-1-loc-1-wea-1-pre-1-yst-2-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-0-pre-0-yst-0-var-0 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-0-pre-0-yst-0-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-0-pre-0-yst-1-var-0 &             0.0 &          242.385 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-0-pre-0-yst-1-var-1 &             0.0 &          242.385 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-0-pre-0-yst-2-var-0 &             0.0 &          264.385 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-0-pre-0-yst-2-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-0-pre-1-yst-0-var-0 &             0.0 &          477.624 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-0-pre-1-yst-0-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-0-pre-1-yst-1-var-0 &             0.0 &          549.803 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-0-pre-1-yst-1-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-0-pre-1-yst-2-var-0 &             0.0 &          665.168 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-0-pre-1-yst-2-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-1-pre-0-yst-0-var-0 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-1-pre-0-yst-0-var-1 &             0.0 &          219.850 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-1-pre-0-yst-1-var-0 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-1-pre-0-yst-1-var-1 &             0.0 &          190.174 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-1-pre-0-yst-2-var-0 &             0.0 &          351.264 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-1-pre-0-yst-2-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-1-pre-1-yst-0-var-0 &             0.0 &          644.004 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-1-pre-1-yst-0-var-1 &             0.0 &          468.023 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-1-pre-1-yst-1-var-0 &             0.0 &          616.545 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-1-pre-1-yst-1-var-1 &             0.0 &          453.519 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-1-pre-1-yst-2-var-0 &             0.0 &          672.336 \\\\\ngid-2-tod-1-dow-1-loc-2-wea-1-pre-1-yst-2-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-0-pre-0-yst-0-var-0 &             0.0 &          160.642 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-0-pre-0-yst-0-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-0-pre-0-yst-1-var-0 &             0.0 &          242.385 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-0-pre-0-yst-1-var-1 &             0.0 &          242.385 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-0-pre-0-yst-2-var-0 &             0.0 &          264.385 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-0-pre-0-yst-2-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-0-pre-1-yst-0-var-0 &             0.0 &          477.624 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-0-pre-1-yst-0-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-0-pre-1-yst-1-var-0 &             0.0 &          549.803 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-0-pre-1-yst-1-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-0-pre-1-yst-2-var-0 &             0.0 &          665.168 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-0-pre-1-yst-2-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-1-pre-0-yst-0-var-0 &             0.0 &          187.966 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-1-pre-0-yst-0-var-1 &             0.0 &          219.850 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-1-pre-0-yst-1-var-0 &             0.0 &          222.244 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-1-pre-0-yst-1-var-1 &             0.0 &          190.174 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-1-pre-0-yst-2-var-0 &             0.0 &          351.264 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-1-pre-0-yst-2-var-1 &             0.0 &          478.770 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-1-pre-1-yst-0-var-0 &             0.0 &          644.004 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-1-pre-1-yst-0-var-1 &             0.0 &          468.023 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-1-pre-1-yst-1-var-0 &             0.0 &          616.545 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-1-pre-1-yst-1-var-1 &             0.0 &          453.519 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-1-pre-1-yst-2-var-0 &             0.0 &          672.336 \\\\\ngid-2-tod-1-dow-1-loc-3-wea-1-pre-1-yst-2-var-1 &             0.0 &          478.770 \\\\\n\\bottomrule\n\\end{tabular}\n'

# %%
s=the_String.replace('\\\\\n','\\')

# %%
sss=s.replace('\\\\midrule\n','\\')

# %%
sss
# Out:
# '\\begin{tabular}{lrr}\n\\toprule\n{} &  truncated\\_mean &  truncated\\_scale \\gid-1-tod-0-dow-0-loc-0-wea-0-pre-0-yst-0-var-0 &             0.0 &            0.000 \\gid-1-tod-0-dow-0-loc-0-wea-0-pre-0-yst-0-var-1 &             0.0 &            0.000 \\gid-1-tod-0-dow-0-loc-0-wea-0-pre-0-yst-1-var-0 &             0.0 &            0.000 \\gid-1-tod-0-dow-0-loc-0-wea-0-pre-0-yst-1-var-1 &             0.0 &            0.000 \\gid-1-tod-0-dow-0-loc-0-wea-0-pre-0-yst-2-var-0 &             0.0 &            0.000 \\gid-1-tod-0-dow-0-loc-0-wea-0-pre-0-yst-2-var-1 &             0.0 &            0.000 \\gid-1-tod-0-dow-0-loc-0-wea-0-pre-1-yst-0-var-0 &             0.0 &            0.000 \\gid-1-tod-0-dow-0-loc-0-wea-0-pre-1-yst-0-var-1 &             0.0 &            0.000 \\gid-1-tod-0-dow-0-loc-0-wea-0-pre-1-yst-1-var-0 &             0.0 &         1077.348 \\gid-1-tod-0-dow-0-loc-0-wea-0-pre-1-yst-1-var-1 &             0.0 &            0.000 \\gid-1-tod-0-dow-0-loc-0-wea-0-pre-1-yst-2-var-0
# ...
